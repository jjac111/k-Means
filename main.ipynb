# %%
# %run main.py
# Out:
# Raw dataset:
#      Media tiempo  Desviacion estandar tiempo  Varianza tiempo  \
# 0        0.099520                    0.245902         0.108890
# 1        0.085819                    0.876726         0.796870
# 2        0.077419                    0.231336         0.099950
# 3        0.102426                    0.291445         0.138865
# 4        0.091737                    0.428982         0.247991
# 5        0.094357                    0.405546         0.227420
# 6        0.090413                    0.650281         0.482250
# 7        0.103414                    0.592027         0.413567
# 8        0.100681                    0.322187         0.160831
# 9        0.051590                    0.931986         0.885151
# 10       0.098185                    1.000000         1.000000
# 11       0.091156                    0.241993         0.106460
# 12       0.125044                    0.727306         0.580764
# 13       0.093368                    0.522717         0.338380
# ...
